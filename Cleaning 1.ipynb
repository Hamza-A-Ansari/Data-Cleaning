# %%
import pandas as pd

# %%
data = pd.read_csv("DATA.csv")

# %%
data
# Out:
#      Name  Sold  Review Rating
# 0     NaN   NaN     NaN    NaN
# 1  Tupple   5.0     NaN   Good
# 2  Orchid  20.0    10.0    NaN
# 3    Rose  10.0     NaN   Best
# 4   Lilly   5.0    20.0    NaN

# %%
a = data.dropna(how = "all",axis=0)
a
# Out:
#      Name  Sold  Review Rating
# 1  Tupple   5.0     NaN   Good
# 2  Orchid  20.0    10.0    NaN
# 3    Rose  10.0     NaN   Best
# 4   Lilly   5.0    20.0    NaN

# %%
a.dropna(how = "any",axis = 1)
# Out:
#      Name  Sold
# 1  Tupple   5.0
# 2  Orchid  20.0
# 3    Rose  10.0
# 4   Lilly   5.0

# %%
a.dropna(subset=["Review","Rating"])
# Out:
# Empty DataFrame
# Columns: [Name, Sold, Review, Rating]
# Index: []

# %%
a
# Out:
#      Name  Sold  Review Rating
# 1  Tupple   5.0     NaN   Good
# 2  Orchid  20.0    10.0    NaN
# 3    Rose  10.0     NaN   Best
# 4   Lilly   5.0    20.0    NaN

# %%
a.fillna(0)
# Out:
#      Name  Sold  Review Rating
# 1  Tupple   5.0     0.0   Good
# 2  Orchid  20.0    10.0      0
# 3    Rose  10.0     0.0   Best
# 4   Lilly   5.0    20.0      0

# %%
b={"Review":"No review","Rating":"No Rating"}
a.fillna(b)
# Out:
#      Name  Sold     Review     Rating
# 1  Tupple   5.0  No review       Good
# 2  Orchid  20.0       10.0  No Rating
# 3    Rose  10.0  No review       Best
# 4   Lilly   5.0       20.0  No Rating

# %%
a.fillna(method="ffill")
# Out:
#      Name  Sold  Review Rating
# 1  Tupple   5.0     NaN   Good
# 2  Orchid  20.0    10.0   Good
# 3    Rose  10.0    10.0   Best
# 4   Lilly   5.0    20.0   Best

# %%
a
# Out:
#      Name  Sold  Review Rating
# 1  Tupple   5.0     NaN   Good
# 2  Orchid  20.0    10.0    NaN
# 3    Rose  10.0     NaN   Best
# 4   Lilly   5.0    20.0    NaN

# %%
a.fillna(method="bfill")
# Out:
#      Name  Sold  Review Rating
# 1  Tupple   5.0    10.0   Good
# 2  Orchid  20.0    10.0   Best
# 3    Rose  10.0    20.0   Best
# 4   Lilly   5.0    20.0    NaN

# %%
c=a["Review"].mean()
c
# Out:
# 15.0

# %%
a.fillna({"Review":c})
# Out:
#      Name  Sold  Review Rating
# 1  Tupple   5.0    15.0   Good
# 2  Orchid  20.0    10.0    NaN
# 3    Rose  10.0    15.0   Best
# 4   Lilly   5.0    20.0    NaN
